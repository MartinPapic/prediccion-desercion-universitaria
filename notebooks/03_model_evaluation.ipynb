# %% [markdown]
# # 3. Evaluación Comparativa (Métricas Crudas)
# Este cuaderno carga los CSV con las métricas exportadas por Kedro para su revisión tabular (los gráficos están en el notebook 6).

# %%
import os
if os.getcwd().endswith('notebooks'):
    os.chdir('..')

# %%
import pandas as pd

supervised_df = pd.read_csv("results/metrics/supervised_metrics.csv")
unsupervised_df = pd.read_csv("results/metrics/unsupervised_metrics.csv")
rl_df = pd.read_csv("results/metrics/rl_metrics.csv")

display(supervised_df)
display(unsupervised_df)
display(rl_df)
# Out:
#                 Model  Accuracy  Precision    Recall        F1
# 0        RandomForest  0.900000   0.705882  0.563492  0.584394
# 1             XGBoost  0.885714   0.621891  0.555556  0.569231
# 2                 SVM  0.900000   0.450000  0.500000  0.473684
# 3  LogisticRegression  0.900000   0.450000  0.500000  0.473684
# 4                 KNN  0.885714   0.449275  0.492063  0.469697
# 5                TPOT  0.900000   0.450000  0.500000  0.473684
#              Model  Silhouette_Score  N_Clusters_Found
# 0           KMeans          0.126691                 3
# 1           DBSCAN         -1.000000                 1
# 2    Agglomerative          0.280661                 3
# 3              GMM          0.155664                 2
# 4  IsolationForest          0.302645                 2
#   Model  Total_Test_Reward  Avg_Reward_per_step
# 0   PPO          52.000000             0.742857
# 1   A2C          54.000000             0.771429
# 2   DQN          56.000000             0.800000
# ...
